# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

# %%
x = [0.1, 0.2, 0.3, 0.4]
a = [-0.62049958, -0.28398668, 0.00660095, 0.24842440]
plt.plot(x, a, "o", label="Puntos dados")

x = np.arange(0.1, 0.2, 0.001)
plt.plot(x, -0.02475 + (x+0.5)*1.032375 + (x+0.5)**2*0.0 + (x+0.5)**3*6.502, label= "Spline 1")

x2 = np.arange(0.2, 0.3, 0.001)
plt.plot(x2, 0.3349375 + 2.2515*(x2+0.25) + 4.8765*(x2+0.25)**2 + (-6.502)*(x2+0.25)**3, label= "Spline 2")

x3 = np.arange(0.3, 0.4, 0.001)

plt.legend(loc = "upper left")
plt.title("Ejericio 3c")
# Out:
# Text(0.5, 1.0, 'Ejericio 3c')
