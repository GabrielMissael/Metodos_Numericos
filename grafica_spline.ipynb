# %%
import numpy as np
import matplotlib.pyplot as plt
import math as mt

# %%
x = [0.1, 0.2, 0.3, 0.4]
a = [-0.62049958, -0.28398668, 0.00660095, 0.24842440]
plt.plot(x, a, "o", label="Puntos dados")

x = np.arange(0.1, 0.2, 0.001)
plt.plot(x, -0.62049958 + (x-0.1)*3.455086933333334 + (x-0.1)**2*0.0 + (x-0.1)**3*-8.995793333333337, label= "Spline 1")

x2 = np.arange(0.2, 0.3, 0.001)
plt.plot(x2, -0.28398668 + (x2-0.2)*3.1852131333333342 + (x2-0.2)**2*-2.6987380000000014 + (x2-0.2)**3*-0.9463033333333606, label= "Spline 2")

x3 = np.arange(0.3, 0.4, 0.001)
plt.plot(x3, 0.00660095 + (x3-0.3)*2.617076433333333 + (x3-0.3)**2*-2.9826290000000095 + (x3-0.3)**3*9.942096666666695, label= "Spline 2")

plt.legend(loc = "upper left")
plt.title("Ejericio 3d")
# Out:
# Text(0.5, 1.0, 'Ejericio 3d')
